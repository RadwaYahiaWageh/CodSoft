# %% [markdown]
# 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Import Dataset

# %%
Adv = pd.read_csv('/content/advertising.csv')
Adv
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# 3. Explore Dataset

# %%
Adv.shape
# Out:
# (200, 4)

# %%
Adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
Adv.describe
# Out:
# <bound method NDFrame.describe of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %% [markdown]
# Check missing data
# Data Cleaning

# %%
Null= Adv.isnull().sum()
Null[Null>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Data Analysis

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(Adv['TV'], ax = axs[0])
plt2 = sns.boxplot(Adv['Newspaper'], ax = axs[1])
plt3 = sns.boxplot(Adv['Radio'], ax = axs[2])
plt.tight_layout()

# %%
sns.boxplot(Adv['Sales'])
plt.show()

# %%
sns.pairplot(Adv, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.show()

# %%
Adv['TV'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
Adv['Radio'].plot.hist(bins=10,color = 'Red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
Adv['Newspaper'].plot.hist(bins=10,color = 'black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Histogram

# %%
sns.heatmap(Adv.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# Split Data

# %%
from sklearn.model_selection import train_test_split
X = Adv['TV']
y = Adv['Sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 20)

# %%
X_train
# Out:
# 134     36.9
# 62     239.3
# 20     218.4
# 21     237.4
# 45     175.1
#        ...
# 148     38.0
# 137    273.7
# 156     93.9
# 15     195.4
# 99     135.2
# Name: TV, Length: 140, dtype: float64

# %%
y_train
# Out:
# 134    10.8
# 62     20.7
# 20     18.0
# 21     17.5
# 45     16.1
#        ...
# 148    10.9
# 137    20.8
# 156    15.3
# 15     22.4
# 99     17.2
# Name: Sales, Length: 140, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

linear_reg = LinearRegression()
linear_reg.fit(X_train_array, y_train)

intercept = linear_reg.intercept_

print("Intercept:", intercept)
# Out:
# Intercept: 7.1646756468037545

# %%
linear_reg.coef_
# Out:
# array([0.05396698])

# %% [markdown]
# Sales=6.948+0.054×TV

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()
